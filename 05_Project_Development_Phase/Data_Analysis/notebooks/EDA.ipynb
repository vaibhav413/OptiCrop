# %% [markdown]
# # OptiCrop Exploratory Data Analysis\n
# This notebook documents and runs the EDA workflow implemented in the modular Python package under `04_Data_Analysis/src`.

# %%
import warnings\n
from pathlib import Path\n
\n
import matplotlib.pyplot as plt\n
import pandas as pd\n
\n
warnings.filterwarnings('ignore')\n
plt.style.use('fivethirtyeight')

# %%
from src.config import AnalysisConfig\n
from run_analysis import run_pipeline\n
\n
project_root = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()\n
if project_root.name != 'Optic-Crop':\n
    project_root = Path('..').resolve()\n
\n
config = AnalysisConfig(project_root=project_root)\n
config

# %%
run_pipeline(config)

# %% [markdown]
# ## Output Locations\n
# - Structured artifacts: `04_Data_Analysis/outputs`\n
# - Plots: `04_Data_Analysis/plots`\n
# - Logs: `04_Data_Analysis/logs/analysis.log`
